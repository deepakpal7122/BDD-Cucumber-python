# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### Q. What is the main component in BDD framework ?
# ###                                      Or
# ### Q. What are the main component we used in BDD Framework ?
#
# ### Ans. These 3 major component we used BDD Appoach.
#     1. Feature File
#     2. Scenario
#     3. Step definication

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ### What is feature file ?
#     The feature file contains different scenario which we have to automate own application and normally. this feature files
#     written by your bussiness Analyst/Sponsor/whoever with your behaviour scenario in it,and.
#
#     this feature file is very easy anyone can understand and the file everyone easily read and understand the feature file
#     is simple language by writting the feature file.
#
#     we use Gherkin language keybord - Given,then,when,but and and.
#
# ### what is feature file?
#     .feature file contain multiple scenario.
#
# ### What is Scenario ?
#     Each scenario contains multiple steps.
#
#
# ### Gherkin keybord we used by using these keyword we can write our feature file along with scenario.
#
# ### Feature:
#     The file should have extension .feature and each feature file should have only one feature. The feature keyword being
#     with the Feature: and after that add, a space and name of the feature will be written.
#
# ### Scenario:
#     Each feature file may have multiple scenarios, and each scenario starts with Scenario: followed by scenario name.
#
#
# ### Given:
#     Is a pre-condition that is a represent precondition.
#     The use of Given keyword is to put the system in a familiar state before the user starts interacting with the system.
#     However, you can omit writing user interactions in Given steps if Given in the “Precondition” step.
#
# ### When:
#     Represting the action or event to perform.
#     When the step is to define action performed by the user.
#
#
# ### Then:
#     Represting the outcome.
#     The use of ‘then’ keyword is to see the outcome after the action in when step. However, you can only verify noticeable
#     changes.
#
# ### And & But
#     suppose some time if you want to multiple action than you can add and keyword.
#     You may have multiple given when or Then.
