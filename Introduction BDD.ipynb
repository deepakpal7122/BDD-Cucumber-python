# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# ![image.png](attachment:image.png)
#
# # What is BDD ?
#
#     BDD Framework is esay to understand anyone can understand. what is happening in the framework, what are the different
#     scenario have covered, what are the different feature have covered and how automation goes, how to generate reports.
#     each and everything can understand easily non-technical people also Understand easily.
#
# ![image-2.png](attachment:image-2.png)
